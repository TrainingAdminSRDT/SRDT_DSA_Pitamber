# %%
stack = []

stack.append(10)
stack.append(20)
stack.append(30)

print("Stack:", stack)

item = stack.pop()
print("Popped:", item)

print("Top element:", stack[-1])

print("Stack after pop:", stack)
# Out:
# Stack: [10, 20, 30]
# Popped: 30
# Top element: 20
# Stack after pop: [10, 20]
